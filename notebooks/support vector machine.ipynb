# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('placement.csv',low_memory=False)
data
# Out:
#                              Email                Name  Gender   10th board  \
# 0            payal_roy79@gmail.com           Payal Roy  Female  State Board
# 1        shreyoshi_dey13@gmail.com       Shreyoshi Dey  Female        WBBSE
# 2          rohan_nandi12@gmail.com         Rohan Nandi    Male  State Board
# 3        smita_agarwal90@gmail.com       Smita Agarwal  Female         CBSE
# 4    samaira_singhania95@gmail.com   Samaira Singhania  Female         ICSE
# ..                             ...                 ...     ...          ...
# 396     mandira_kapoor63@gmail.com      Mandira Kapoor  Female         ICSE
# 397        smita_yadav92@gmail.com         Smita Yadav  Female  State Board
# 398       manish_sinha90@gmail.com        Manish Sinha    Male         CBSE
# 399          pawan_sah12@gmail.com           Pawan Sah    Male         ICSE
# 400  abhijit_chatterjee6@gmail.com  Abhijit Chatterjee    Male        WBBSE
#
#      10th marks         12th board  12th marks  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Email                    401 non-null    object
#  1   Name                     401 non-null    object
#  2   Gender                   401 non-null    object
#  3   10th board               401 non-null    object
#  4   10th marks               401 non-null    float64
#  5   12th board               401 non-null    object
#  6   12th marks               401 non-null    float64
#  7   Stream                   401 non-null    object
#  8   Cgpa                     401 non-null    float64
#  9   Internships(Y/N)         401 non-null    object
#  10  Training(Y/N)            401 non-null    object
#  11  Backlog in 5th sem       401 non-null    object
#  12  Innovative Project(Y/N)  401 non-null    object
#  13  Communication level      401 non-null    int64
# ...

# %%
data.describe()
# Out:
#        10th marks  12th marks        Cgpa  Communication level
# count  401.000000  401.000000  401.000000           401.000000
# mean    84.512718   78.798828    8.467855             2.922693
# std      9.779359   10.418821    4.154455             1.378952
# min     32.000000   45.000000    5.500000             1.000000
# 25%     77.600000   70.000000    7.620000             2.000000
# 50%     85.200000   80.500000    8.270000             3.000000
# 75%     92.000000   87.300000    8.940000             4.000000
# max    100.000000   97.000000   90.000000             5.000000

# %%
data.shape
# Out:
# (401, 16)

# %%
data.isnull().sum()
# Out:
# Email                      0
# Name                       0
# Gender                     0
# 10th board                 0
# 10th marks                 0
# 12th board                 0
# 12th marks                 0
# Stream                     0
# Cgpa                       0
# Internships(Y/N)           0
# Training(Y/N)              0
# Backlog in 5th sem         0
# Innovative Project(Y/N)    0
# Communication level        0
# Technical Course(Y/N)      0
# Placement(Y/N)?            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Placement(Y/N)?'].value_counts()
# Out:
# Placement(Y/N)?
# Not Placed    202
# Placed        199
# Name: count, dtype: int64

# %%
data['Stream'].unique()
# Out:
# array(['Mechanical Engineering',
#        'Electronics and Communication Engineering',
#        'Information Technology', 'Computer Science in AIML',
#        'Computer Science and Engineering', 'Production Engineering',
#        'Civil Engineering', 'Electrical Engineering',
#        'Computer Science in Data Science',
#        'Electrical and Electronics Engineering',
#        'IMsc Maths and Computing', 'Computer Science and Design',
#        'Electronics and Communication and Engineeing',
#        'Chemical Engineering', 'Electronics Engineering',
#        'Electronic Engineering'], dtype=object)

# %%
sns.pairplot(data)

# %%
print(data['Placement(Y/N)?'].value_counts())
print(data['Training(Y/N)'].value_counts())
print(data['Innovative Project(Y/N)'].value_counts())
print(data['Technical Course(Y/N)'].value_counts())
print(data['Internships(Y/N)'].value_counts())
print(data['Backlog in 5th sem'].value_counts())
# Out:
# Placement(Y/N)?
# Not Placed    202
# Placed        199
# Name: count, dtype: int64
# Training(Y/N)
# Yes    216
# No     185
# Name: count, dtype: int64
# Innovative Project(Y/N)
# Yes    295
# No     105
# yes      1
# Name: count, dtype: int64
# Technical Course(Y/N)
# Yes     308
# No       92
# Yess      1
# Name: count, dtype: int64
# Internships(Y/N)
# Yes    229
# No     172
# Name: count, dtype: int64
# Backlog in 5th sem
# No     300
# Yes    101
# Name: count, dtype: int64

# %%
# Convert categorical columns to numeric for plotting
data['Internships(Y/N)'] = data['Internships(Y/N)'].map({'No': 0, 'Yes': 1})
data['Placement(Y/N)?'] = data['Placement(Y/N)?'].map({'Not Placed': 0, 'Placed': 1})
data['Innovative Project(Y/N)'] = data['Innovative Project(Y/N)'].map({'No': 0, 'Yes': 1,'yes':1})
data['Technical Course(Y/N)'] = data['Technical Course(Y/N)'].map({'No': 0, 'Yes': 1,'Yess':1})
data['Training(Y/N)']=data['Training(Y/N)'].map({'Yes':1,'No':0})
data['Backlog in 5th sem']=data['Backlog in 5th sem'].map({'Yes':1,'No':0})

# %%
data.head()
# Out:
#                            Email               Name  Gender   10th board  \
# 0          payal_roy79@gmail.com          Payal Roy  Female  State Board
# 1      shreyoshi_dey13@gmail.com      Shreyoshi Dey  Female        WBBSE
# 2        rohan_nandi12@gmail.com        Rohan Nandi    Male  State Board
# 3      smita_agarwal90@gmail.com      Smita Agarwal  Female         CBSE
# 4  samaira_singhania95@gmail.com  Samaira Singhania  Female         ICSE
#
#    10th marks         12th board  12th marks  \
# 0        96.7               CBSE        70.2
# 1        96.2             WBCHSE        90.6
# 2        97.5               CBSE        69.6
# 3        96.9  Other state Board        77.6
# 4        99.1               CBSE        62.8
#
#                                       Stream  Cgpa  Internships(Y/N)  \
# 0                     Mechanical Engineering  7.37                 0
# 1  Electronics and Communication Engineering  9.35                 0
# ...

# %%
data=data.rename(columns={'10th board':'sslc_board','10th marks':'sslc_mark','12th board':'hsc_board','12th marks':'hsc_mark','Internships(Y/N)':'Internship','Training(Y/N)':'Training','Innovative Project(Y/N)':'Project','Technical Course(Y/N)':'Technical_course','Placement(Y/N)?':'Placement'})

# %%
data.head()
# Out:
#                            Email               Name  Gender   sslc_board  \
# 0          payal_roy79@gmail.com          Payal Roy  Female  State Board
# 1      shreyoshi_dey13@gmail.com      Shreyoshi Dey  Female        WBBSE
# 2        rohan_nandi12@gmail.com        Rohan Nandi    Male  State Board
# 3      smita_agarwal90@gmail.com      Smita Agarwal  Female         CBSE
# 4  samaira_singhania95@gmail.com  Samaira Singhania  Female         ICSE
#
#    sslc_mark          hsc_board  hsc_mark  \
# 0       96.7               CBSE      70.2
# 1       96.2             WBCHSE      90.6
# 2       97.5               CBSE      69.6
# 3       96.9  Other state Board      77.6
# 4       99.1               CBSE      62.8
#
#                                       Stream  Cgpa  Internship  Training  \
# 0                     Mechanical Engineering  7.37           0         1
# 1  Electronics and Communication Engineering  9.35           0         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Email                401 non-null    object
#  1   Name                 401 non-null    object
#  2   Gender               401 non-null    object
#  3   sslc_board           401 non-null    object
#  4   sslc_mark            401 non-null    float64
#  5   hsc_board            401 non-null    object
#  6   hsc_mark             401 non-null    float64
#  7   Stream               401 non-null    object
#  8   Cgpa                 401 non-null    float64
#  9   Internship           401 non-null    int64
#  10  Training             401 non-null    int64
#  11  Backlog in 5th sem   401 non-null    int64
#  12  Project              401 non-null    int64
#  13  Communication level  401 non-null    int64
#  14  Technical_course     401 non-null    int64
# ...

# %%
num=data.select_dtypes(include='number')

# %%
num
# Out:
#      sslc_mark  hsc_mark  Cgpa  Internship  Training  Backlog in 5th sem  \
# 0         96.7      70.2  7.37           0         1                   0
# 1         96.2      90.6  9.35           0         0                   0
# 2         97.5      69.6  7.84           0         1                   0
# 3         96.9      77.6  7.87           1         0                   1
# 4         99.1      62.8  9.26           1         1                   0
# ..         ...       ...   ...         ...       ...                 ...
# 396       88.8      89.1  8.34           1         1                   0
# 397       86.7      86.7  7.77           1         0                   0
# 398       83.5      61.1  8.85           0         0                   0
# 399       99.8      75.4  7.89           1         1                   1
# 400       94.2      90.0  7.89           1         0                   0
#
#      Project  Communication level  Technical_course  Placement
# ...

# %%
sns.heatmap(num.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score

# %%
data=data.drop(['Name','Email'],axis=1)

# %%
data_encoded=pd.get_dummies(data,columns=['sslc_board','hsc_board','Stream','Gender'],drop_first=True)

# %%
data_encoded.head()
# Out:
#    sslc_mark  hsc_mark  Cgpa  Internship  Training  Backlog in 5th sem  \
# 0       96.7      70.2  7.37           0         1                   0
# 1       96.2      90.6  9.35           0         0                   0
# 2       97.5      69.6  7.84           0         1                   0
# 3       96.9      77.6  7.87           1         0                   1
# 4       99.1      62.8  9.26           1         1                   0
#
#    Project  Communication level  Technical_course  Placement  ...  \
# 0        0                    3                 1          0  ...
# 1        1                    4                 0          0  ...
# 2        1                    3                 1          1  ...
# 3        1                    2                 1          0  ...
# 4        1                    1                 1          0  ...
#
#    Stream_Electrical and Electronics Engineering  \
# 0                                          False
# ...

# %%
X=data_encoded.drop(['Placement'],axis=1)
y=data_encoded['Placement']

# %%
X.head()
# Out:
#    sslc_mark  hsc_mark  Cgpa  Internship  Training  Backlog in 5th sem  \
# 0       96.7      70.2  7.37           0         1                   0
# 1       96.2      90.6  9.35           0         0                   0
# 2       97.5      69.6  7.84           0         1                   0
# 3       96.9      77.6  7.87           1         0                   1
# 4       99.1      62.8  9.26           1         1                   0
#
#    Project  Communication level  Technical_course  sslc_board_ICSE  ...  \
# 0        0                    3                 1            False  ...
# 1        1                    4                 0            False  ...
# 2        1                    3                 1            False  ...
# 3        1                    2                 1            False  ...
# 4        1                    1                 1             True  ...
#
#    Stream_Electrical and Electronics Engineering  \
# 0                                          False
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Placement, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
scalar=StandardScaler()
X_train=scalar.fit_transform(X_train)
X_test=scalar.transform(X_test)

# %%
svm_model=SVC(kernel='rbf')
svm_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=svm_model.predict(X_test)
print("Accuracy: ",accuracy_score(y_test,y_pred))
print("Classification report: ",classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.8888888888888888
# Classification report:                precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88        40
#            1       0.85      0.95      0.90        41
#
#     accuracy                           0.89        81
#    macro avg       0.90      0.89      0.89        81
# weighted avg       0.89      0.89      0.89        81

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'poly', 'sigmoid']  # You can try 'linear' as well
}

# Set up the GridSearchCV
grid_search = GridSearchCV(SVC(), param_grid, refit=True, verbose=2, cv=5)

# Train using GridSearchCV
grid_search.fit(X_train, y_train)

# Print the best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Predict and evaluate using the best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
